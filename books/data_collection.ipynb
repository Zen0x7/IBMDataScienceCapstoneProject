# %%
import requests
import pandas as pd
import folium
from IPython.display import HTML, display

def get_json_from(url):
  try:
      # Hacer la solicitud GET
      response = requests.get(url)
      # Verificar si la solicitud fue exitosa
      if response.status_code == 200:
          # Convertir la respuesta a JSON
          return response.json()
      else:
          print(f"Error: {response.status_code} - {response.reason}")
  except Exception as e:
      print(f"Ha ocurrido un error: {e}")

launchpads = pd.json_normalize(get_json_from("https://api.spacexdata.com/v3/launchpads"))
launches = pd.json_normalize(get_json_from("https://api.spacexdata.com/v3/launches"))

# %%
launchpads
# Out:
#    id             name              status         vehicles_launched  \
# 0   5      VAFB SLC 3W             retired                [Falcon 1]
# 1   2     CCAFS SLC 40              active                [Falcon 9]
# 2   8             STLS  under construction                [Falcon 9]
# 3   1  Kwajalein Atoll             retired                [Falcon 1]
# 4   6      VAFB SLC 4E              active                [Falcon 9]
# 5   4       KSC LC 39A              active  [Falcon 9, Falcon Heavy]
#
#    attempted_launches  successful_launches  \
# 0                   0                    0
# 1                  61                   59
# 2                   0                    0
# 3                   5                    2
# 4                  16                   16
# 5                  27                   26
#
#                                            wikipedia  \
# 0  https://en.wikipedia.org/wiki/Vandenberg_AFB_S...
# 1  https://en.wikipedia.org/wiki/Cape_Canaveral_A...
# 2  https://en.wikipedia.org/wiki/SpaceX_South_Tex...
# 3        https://en.wikipedia.org/wiki/Omelek_Island
# 4  https://en.wikipedia.org/wiki/Vandenberg_AFB_S...
# 5  https://en.wikipedia.org/wiki/Kennedy_Space_Ce...
#
#                                              details          site_id  \
# 0  SpaceX original west coast launch pad for Falc...      vafb_slc_3w
# 1  SpaceX primary Falcon 9 launch pad, where all ...     ccafs_slc_40
# 2  SpaceX new launch site currently under constru...             stls
# 3  SpaceX original launch site, where all of the ...  kwajalein_atoll
# 4  SpaceX primary west coast launch pad for polar...      vafb_slc_4e
# 5  NASA historic launch pad that launched most of...       ksc_lc_39a
#
#                                       site_name_long  \
# 0  Vandenberg Air Force Base Space Launch Complex 3W
# 1  Cape Canaveral Air Force Station Space Launch ...
# 2                     SpaceX South Texas Launch Site
# 3                      Kwajalein Atoll Omelek Island
# 4  Vandenberg Air Force Base Space Launch Complex 4E
# 5   Kennedy Space Center Historic Launch Complex 39A
#
#                location.name   location.region  location.latitude  \
# 0  Vandenberg Air Force Base        California          34.644090
# 1             Cape Canaveral           Florida          28.561857
# 2         Boca Chica Village             Texas          25.997264
# 3              Omelek Island  Marshall Islands           9.047721
# 4  Vandenberg Air Force Base        California          34.632093
# 5             Cape Canaveral           Florida          28.608058
#
#    location.longitude
# 0         -120.593144
# 1          -80.577366
# 2          -97.156085
# 3          167.743129
# 4         -120.610829
# 5          -80.603956

# %%
launches
# Out:
#      flight_number                 mission_name mission_id  upcoming  \
# 0                1                    FalconSat         []     False
# 1                2                      DemoSat         []     False
# 2                3                  Trailblazer         []     False
# 3                4                       RatSat         []     False
# 4                5                     RazakSat         []     False
# ..             ...                          ...        ...       ...
# 106            107                       Crew-1  [EE86F74]     False
# 107            108  Sentinel-6 Michael Freilich         []     False
# 108            109           Starlink-15 (v1.0)         []     False
# 109            110                       CRS-21  [EE86F74]      True
# 110            110                        SXM-7         []      True
#
#     launch_year  launch_date_unix           launch_date_utc  \
# 0          2006        1143239400  2006-03-24T22:30:00.000Z
# 1          2007        1174439400  2007-03-21T01:10:00.000Z
# 2          2008        1217734440  2008-08-03T03:34:00.000Z
# 3          2008        1222643700  2008-09-28T23:15:00.000Z
# 4          2009        1247456100  2009-07-13T03:35:00.000Z
# ..          ...               ...                       ...
# 106        2020        1605486420  2020-11-16T00:27:00.000Z
# 107        2020        1605979020  2020-11-21T17:17:00.000Z
# 108        2020        1603553460  2020-10-24T15:31:00.000Z
# 109        2020        1607271420  2020-12-06T16:17:00.000Z
# 110        2020        1607880600  2020-12-13T17:30:00.000Z
#
#              launch_date_local  is_tentative tentative_max_precision  ...  \
# 0    2006-03-25T10:30:00+12:00         False                    hour  ...
# 1    2007-03-21T13:10:00+12:00         False                    hour  ...
# 2    2008-08-03T15:34:00+12:00         False                    hour  ...
# 3    2008-09-28T11:15:00+12:00         False                    hour  ...
# 4    2009-07-13T15:35:00+12:00         False                    hour  ...
# ..                         ...           ...                     ...  ...
# 106  2020-11-15T19:27:00-05:00         False                    hour  ...
# 107  2020-11-21T09:17:00-08:00         False                    hour  ...
# 108  2020-10-24T11:31:00-04:00         False                    hour  ...
# 109  2020-12-06T11:17:00-05:00         False                    hour  ...
# 110  2020-12-13T12:30:00-05:00         False                    hour  ...
#
#      timeline.stage2_rp1_loading  timeline.seco-3 timeline.seco-4  \
# 0                            NaN              NaN             NaN
# 1                            NaN              NaN             NaN
# 2                            NaN              NaN             NaN
# 3                            NaN              NaN             NaN
# 4                            NaN              NaN             NaN
# ..                           ...              ...             ...
# 106                          NaN              NaN             NaN
# 107                          NaN              NaN             NaN
# 108                          NaN              NaN             NaN
# 109                          NaN              NaN             NaN
# 110                          NaN              NaN             NaN
#
#              last_date_update       last_ll_launch_date  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ..                        ...                       ...
# 106  2020-11-13T21:31:19.000Z                      None
# 107  2020-11-17T19:27:21.000Z  2020-11-21T17:17:00.000Z
# 108                       NaN                       NaN
# 109  2020-12-05T13:04:54.000Z                      None
# 110  2020-12-13T17:03:48.000Z                      None
#
#                last_ll_update     last_wiki_launch_date  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ..                        ...                       ...
# 106                      None  2020-11-16T00:27:00.000Z
# 107  2020-11-05T23:48:07.000Z  2020-11-21T17:17:00.000Z
# 108                       NaN                       NaN
# 109                      None  2020-12-06T16:17:00.000Z
# 110                      None  2020-12-13T17:30:00.000Z
#
#                        last_wiki_revision          last_wiki_update  \
# 0                                     NaN                       NaN
# 1                                     NaN                       NaN
# 2                                     NaN                       NaN
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
# ..                                    ...                       ...
# 106  90e9da15-25f7-11eb-badd-0e3a392f3e47  2020-11-13T21:31:19.000Z
# 107  e93220d1-290a-11eb-bd82-0e4885cc0cd7  2020-11-17T19:27:21.000Z
# 108                                   NaN                       NaN
# 109  774e7809-36fa-11eb-a5dc-0e33339b29dd  2020-12-05T13:04:54.000Z
# 110  2aa9a2fe-3d65-11eb-abb7-0e98a0ca8665  2020-12-13T17:03:48.000Z
#
#     launch_date_source
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 106               wiki
# 107               wiki
# 108                NaN
# 109               wiki
# 110               wiki
#
# [111 rows x 99 columns]
